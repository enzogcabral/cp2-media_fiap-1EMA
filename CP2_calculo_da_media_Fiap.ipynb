# %% [markdown]
# <a href="https://colab.research.google.com/github/enzogcabral/cp2-media_fiap-1EMA/blob/main/CP2_calculo_da_media_Fiap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **calculo do primeiro semestre**

# %% [markdown]
# **Calcular a media dos checkpoints da fiap**

# %%
# calculo de media dos checkpoints
# 3 CPs obrigatorias ----> input
CP1, CP2, CP3 = input("insira as notas dos checkpoints: ").split()
CP1 = float(CP1)
CP2 = float(CP2)
CP3 = float(CP3)
# Out:
# insira as notas dos checkpoints: 10 10 10

# %%
# eliminar menor nota
D1 = min(CP1, CP2, CP3)
D1
# Out:
# 10.0

# %%
# calcular media das duas maiores notas
CPM1 = (CP3 + CP2 + CP1 - D1) / 2
CPM1
# Out:
# 10.0

# %% [markdown]
# Calculo da media da Sprint

# %%
SP1 ,SP2 = input("insira as notas da sprint: ").split()
SP1 = float(SP1)
SP2 = float(SP2)
SPF1 = (SP1 + SP2) / 2
SPF1
# Out:
# insira as notas da sprint: 10 10
# 10.0

# %% [markdown]
# media parcial(e quanto falta para a passar com a gs1)

# %%
MP1 = SPF1*0.2 + CPM1*0.2
print(MP)
MTP1 = 6 - MP

print(f"voce precisa {MTP1/0.6} para passar")
# Out:
# 4.0
# voce precisa 3.3333333333333335 para passar

# %% [markdown]
# Valor da Global Solution

# %%
GS1 = input("insira a nota da GS: ")
GS1 = float(GS1)
GS1
# Out:
# insira a nota da GS: 3.4
# 3.4

# %% [markdown]
# Calculo Da media do 1 semestre

# %%
MS1 = GS1*0.6 + MP1
MS1
# Out:
# 6.04

# %% [markdown]
# calculo do segundo semestre

# %%
CP4, CP5, CP6 = input("insira as notas dos checkpoints: ").split()
CP4 = float(CP6)
CP5 = float(CP5)
CP6 = float(CP4)
# Out:
# insira as notas dos checkpoints: 10 9 6

# %%
# eliminar menor nota
D2 = min(CP4, CP5, CP6)
D2
# Out:
# 6.0

# %%
# calcular media das duas maiores notas
CPM2 = (CP4 + CP5 + CP6 - D1) / 2
CPM2
# Out:
# 8.0

# %%
SP3,SP4 = input("insira as notas da sprint: ").split()
SP4 = float(SP4)
SP3 = float(SP3)
SPF2 = (SP4 + SP3) / 2
SPF2
# Out:
# insira as notas da sprint: 7 9
# 8.0

# %%
# media parcial2(e quanto falta para a passar com a gs2)
MP2 = SPF2*0.2 + CPM2*0.2
print(MP)
MTP2 = 6 - MP

print(f"voce precisa {MTP2/0.6} para passar")

# %% [markdown]
# calcular nota semestre 2

# %%
GS2 = input("insira a nota da GS: ")
GS2 = float(GS2)
GS2
# Out:
# insira a nota da GS: 8
# 8.0

# %%
MS2 = GS2*0.6 + MP2
MS2
# Out:
# 8.0

# %% [markdown]
# calcular media final

# %%
MF=(MS1*0.4)+(MS2*0.6)
MF
# Out:
# 7.64

# %% [markdown]
# texto se o aluno passou de ano

# %%
if MF >= 6:
  print("aprovado")
elif MF>4:
  print("em exame")
  EX = input("insira a nota do exame: ")
  EX = float(EX)
  MF = (EX + MF) / 2
  if MF >= 6:
    print("aprovado")
else:
  print("reprovado")
# Out:
# aprovado
